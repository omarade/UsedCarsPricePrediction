# %% [markdown]
# # Predicting used cars prices using machine learning

# %% [markdown]
# This notebook looks into using various Python-based machine learning and data science libraries in an attempt to build a machine learning model capable of predicting the right price for a used car, to potentially help people who are looking to buy one not to overpay for it
#
# The following approach will be taken:
# 1. Problem definition
# 2. Data
# 3. Evaluation
# 4. Features
# 5. Modeling
# 6. Experimentation
#
# This approach is itertive and it is possible at any point to go back and work further on a prevouis step in the process.
#
# ## 1. Problem Definition
# In a statment
# > Given the details and specs of a used car, is it possible to predict a fair price for it?
#
# ## 2. Data
# The dataset that came from Kaggle but originally it was scraped off Craigslist
# https://www.kaggle.com/datasets/austinreese/craigslist-carstrucks-data/data
#
# # 3. Evaluation
# > The model's effectiveness can be assessed through various metrics such as RMSE (Root Mean Squared Error), RMSLE (Root Mean Squared Log Error), MAE (Mean Absolute Error), R-squared etc. the model results will be considered good if it is able to accurately predict used cars prices within a 10% error margin.
#
# # 4. Features
# **Data Dictionary**:
# 1. **id** - entry id  this***
# 2. **url** - kisting URL
# 3. **region** - Craigslist region
# 4. **region_url** - region URL
# 5. **price** - entry price in Dollars
# 6. **year** - manufacturing year
# 7. **manufacturer** - manufacturer of vehicle
# 8. **model** - model of vehicle
# 9. **condition** - condition of vehecle
# 10. **cylinders** - number of cylinders
# 11. **fuel** - fuel type
# 12. **odometer** - miles travled by vehicle
# 13. **title_status** - title status of vehicle
# 14. **transmission** - transmission of vehicle
# 15. **VIN** - vehicle identification number   this***
# 16. **drive** - type of drive
# 17. **size** - size of vehicle
# 18. **type** - generic type of vehicle
# 19. **paint_color** - color of vehicle
# 20. **image_url** - vehicle image URL
# 21. **description** - listed description of vehicle    this**
# 22. **county** - useless column left in by mistake **(will be dropped)**
# 23. **state** - state of listing
# 24. **lat** - latitude of listing    this***
# 25. **long** - longitude of listing    this***
# 26. **posting_date** - date of listing

# %% [markdown]
# ## Importing the required tools

# %%
# %matplotlib inline 
# Make plots appear inside the notebook

# EDA (exploratory data analysis) and plotting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# import missingno as msno 

# Models from Scikit-Learn
import sklearn
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# Model evaluation 
from sklearn.metrics import mean_absolute_error, mean_squared_log_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %% [markdown]
# ## Import & Anonymize Data

# %%
# Import the dataset
df = pd.read_csv("data/vehicles.csv", low_memory=False, parse_dates=["year"])

df.drop(columns=["VIN", "lat", "long", "url", "region_url", "image_url"], inplace=True)
df
# Out:
#                 id                  region  price       year manufacturer  \
# 0       7222695916                prescott   6000        NaT          NaN
# 1       7218891961            fayetteville  11900        NaT          NaN
# 2       7221797935            florida keys  21000        NaT          NaN
# 3       7222270760  worcester / central MA   1500        NaT          NaN
# 4       7210384030              greensboro   4900        NaT          NaN
# ...            ...                     ...    ...        ...          ...
# 426875  7301591192                 wyoming  23590 2019-01-01       nissan
# 426876  7301591187                 wyoming  30590 2020-01-01        volvo
# 426877  7301591147                 wyoming  34990 2020-01-01     cadillac
# 426878  7301591140                 wyoming  28990 2018-01-01        lexus
# 426879  7301591129                 wyoming  30590 2019-01-01          bmw
#
#                            model condition    cylinders    fuel  odometer  \
# 0                            NaN       NaN          NaN     NaN       NaN
# 1                            NaN       NaN          NaN     NaN       NaN
# 2                            NaN       NaN          NaN     NaN       NaN
# 3                            NaN       NaN          NaN     NaN       NaN
# 4                            NaN       NaN          NaN     NaN       NaN
# ...                          ...       ...          ...     ...       ...
# 426875         maxima s sedan 4d      good  6 cylinders     gas   32226.0
# 426876  s60 t5 momentum sedan 4d      good          NaN     gas   12029.0
# 426877          xt4 sport suv 4d      good          NaN  diesel    4174.0
# 426878           es 350 sedan 4d      good  6 cylinders     gas   30112.0
# 426879  4 series 430i gran coupe      good          NaN     gas   22716.0
#
#        title_status transmission drive size       type paint_color  \
# 0               NaN          NaN   NaN  NaN        NaN         NaN
# 1               NaN          NaN   NaN  NaN        NaN         NaN
# 2               NaN          NaN   NaN  NaN        NaN         NaN
# 3               NaN          NaN   NaN  NaN        NaN         NaN
# 4               NaN          NaN   NaN  NaN        NaN         NaN
# ...             ...          ...   ...  ...        ...         ...
# 426875        clean        other   fwd  NaN      sedan         NaN
# 426876        clean        other   fwd  NaN      sedan         red
# 426877        clean        other   NaN  NaN  hatchback       white
# 426878        clean        other   fwd  NaN      sedan      silver
# 426879        clean        other   rwd  NaN      coupe         NaN
#
#                                               description  county state  \
# 0                                                     NaN     NaN    az
# 1                                                     NaN     NaN    ar
# 2                                                     NaN     NaN    fl
# 3                                                     NaN     NaN    ma
# 4                                                     NaN     NaN    nc
# ...                                                   ...     ...   ...
# 426875  Carvana is the safer way to buy a car During t...     NaN    wy
# 426876  Carvana is the safer way to buy a car During t...     NaN    wy
# 426877  Carvana is the safer way to buy a car During t...     NaN    wy
# 426878  Carvana is the safer way to buy a car During t...     NaN    wy
# 426879  Carvana is the safer way to buy a car During t...     NaN    wy
#
#                     posting_date
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 426875  2021-04-04T03:21:31-0600
# 426876  2021-04-04T03:21:29-0600
# 426877  2021-04-04T03:21:17-0600
# 426878  2021-04-04T03:21:11-0600
# 426879  2021-04-04T03:21:07-0600
#
# [426880 rows x 20 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# Import the dataset
# df = pd.read_csv("data/vehicles.csv", low_memory=False, parse_dates=["year"])

# %% [markdown]
# ### Methods

# %%
def visualize_distribution(df, column, label, logscale=False):
    """
    Plot the distribution of a spicific column in a dataframe
    """
    # Subplot of distribution
    fig, (ax0, ax1) = plt.subplots(nrows=2,
                                    ncols=1,
                                    figsize=(35, 30),
                                    sharex=False)

    # Add data to ax0
    red_square = dict(markerfacecolor="lightblue", marker="s")
    ax0.boxplot(df[column], vert=False, flierprops=red_square);
    # Add data to ax1
    ax1.hist(df[column], bins=6);

    # Customize ax0
    ax0.set_title(label="Boxplot ", fontsize=40);
    ax0.set_xlabel(label, fontsize=40)
    ax0.set_xscale('log')
    ax0.tick_params(axis="both", which="major", labelsize=20)

    #ax0.bar_label(fontsize=20)

    # Customize ax1    
    ax1.set_title(label="Histogram ", fontsize=40);
    ax1.set_xlabel(label, fontsize=40)
    
    if logscale:
        ax1.set_yscale('log')
    
    ax1.set_ylabel("Distribution", fontsize=30);
    ax1.tick_params(axis="both", which="major", labelsize=20)

    # Add a title to the figure
    fig.suptitle("The distribution of " + label, fontsize=50, fontweight="bold");

# %%
# Calculate the average price of cars for a given column
def calculate_average_price_by_column(column_name, df, items_num=None):
    """
    Calculate the average price of cars for a given column.
    
    Parameters:
        column_name (str): The name of the column to calculate the average against (e.g., 'price').
        df (DataFrame): DataFrame containing the car data with columns 'column_name' and 'price'.
        items_num (int, optional): The number of top categories to include in the calculation. If not specified, all categories will be included.
    """ 
    # Group by the specified column and calculate the mean price for each category
    avg_value = df.groupby(column_name)['price'].mean().sort_values(ascending=False)

    # Sort the average values in descending order and limit to the specified number of items
    if items_num is not None:
        avg_value = avg_value.nlargest(items_num)

    avg_value_dict = avg_value.to_dict()

    print(f"\033[1;35mBelow are the average prices per {column_name} values:\033[0m")
    # Iterate over the dictionary and print each value
    for category, price in avg_value.items():
        # Apply custom formatting as needed
        formatted_price = f"${price:.2f}"  # Format the price to two decimal places with a dollar sign
        print(f"\033[1;4;31m{category.capitalize()}\033[0m: \033[1;32m{formatted_price}\033[0m")

# %%
df.groupby("region")['price'].mean().sort_values(ascending=False)
# Out:
# region
# frederick              4.914334e+06
# delaware               3.205056e+06
# humboldt county        2.902730e+06
# modesto                1.401324e+06
# knoxville              1.369993e+06
#                            ...
# sioux city             9.649819e+03
# southeast IA           9.624103e+03
# klamath falls          9.550169e+03
# west virginia (old)    9.423750e+03
# siskiyou county        8.293855e+03
# Name: price, Length: 404, dtype: float64

# %%
# Calculate the distribuation of the price per a column
def calculate_price_quartiles_by_column(column_name, df, items_num=None):
    """
    Calculate quartiles for each group in a specified column.
    
    Parameters:
        column_name (str): The name of the column to calculate quartiles for.
        df (DataFrame): DataFrame containing the data with the specified column.
    
    Returns:
        None
    """
    # Calculate quartiles for each group
    summary_stats = df.groupby(column_name)['price'].describe().sort_values(by='50%', ascending=False)
    
    # Limit to the specified number of items if items_num is provided
    if items_num is not None:
        summary_stats = summary_stats.nlargest(items_num, '50%')
    
    q1_values = summary_stats['25%']
    median_values = summary_stats['50%']
    q3_values = summary_stats['75%']

    # Print quartiles for each group
    print(f"\033[1;35mBelow are the Q1, Q2 (median), & Q3 values:")
    print(f"\033[1;31mQ1 (First Quartile):\033[0m represents the lower quartile, 25% of the data points are less than or equal to Q1")
    print(f"\033[1;31mQ2 (Median):\033[0m represents the middle quartile, dividing the dataset into two equal parts")
    print(f"\033[1;31mQ3 (Third Quartile):\033[0m represents the upper quartile, 75% of the data points are less than or equal to Q3\n")
    
    print(f"\033[1;3;4;35mPrice distribution per {column_name}:")
    for group, q1, median, q3 in zip(summary_stats.index, q1_values, median_values, q3_values):
        # Capitalize group only if it's a string
        if isinstance(group, str):
            group = group.capitalize()
            
        print(f"\033[1;4;31m{group}\033[0m: Q1: \033[1;32m{q1}\033[0m, Median: \033[1;32m{median}\033[0m, Q3: \033[1;32m{q3}\033[0m")

# %%
# Calculate the distribuation of numerical values
def calculate_numerical_quartiles(column_name, df):
    """
    Calculate quartiles for a specified column.
    
    Parameters:
        column_name (str): The name of the column to calculate quartiles for.
        df (DataFrame): DataFrame containing the data with the specified column.
    
    Returns:
        None
    """
    q1 = df[column_name].quantile(0.25)
    median = df[column_name].quantile(0.50)
    q3 = df[column_name].quantile(0.75)
 
    # Calculate IQR
    IQR = q3 - q1
    
    # Define the lower and upper bounds for outliers
    lower_bound = q1 - 1.5 * IQR
    upper_bound = q3 + 1.5 * IQR

    # Print quartiles for each group
    print(f"\033[1;35mBelow are the Q1, Q2 (median), & Q3 values:")
    print(f"\033[1;31mQ1 (First Quartile):\033[0m represents the lower quartile, 25% of the data points are less than or equal to Q1")
    print(f"\033[1;31mQ2 (Median):\033[0m represents the middle quartile, dividing the dataset into two equal parts")
    print(f"\033[1;31mQ3 (Third Quartile):\033[0m represents the upper quartile, 75% of the data points are less than or equal to Q3\n")
    
    print(f"\033[1;3;4;35mDistribution for {column_name}:\033[0m")    
    print(f"Lower bound: \033[1;32m{lower_bound}\033[0m, Q1: \033[1;32m{q1}\033[0m, Median: \033[1;32m{median}\033[0m, Q3: \033[1;32m{q3}\033[0m, Upper bound: \033[1;32m{upper_bound}\033[0m")

    return lower_bound, upper_bound

# %%
# Plot column values frequancy
def plot_column_frequancy(column_name, df, items_num=None):
    """
    Plot the frequancy of a specified column in a DataFrame using a bar chart.
    
    Parameters:
        column_name (str): The name of the column to plot the bar chart for.
        df (DataFrame): DataFrame containing the data.
        items_num (int): The number of categories to plot from the provided column in column_name. if not provided, items_num will be the count of the categories in the column
    Returns:
        None
    """
    # Group by the specified column and count the number of occurrences
    counts_per_category = df[column_name].value_counts()
    
    if items_num is None:
        items_num = len(counts_per_category)

    # Create a bar plot
    fig, ax = plt.subplots(figsize=(10, 6))
    bar = ax.bar(counts_per_category.index.tolist()[:items_num], counts_per_category.iloc[:items_num])

    # Customize the bar plot
    ax.set(title=f"Used Cars per {column_name.capitalize()} / Top {items_num}",
           xlabel=column_name.capitalize(),
           ylabel='Number of Cars')

    plt.show()

# %%
# Plot the price distribution for a specified column
def plot_price_distribution_per_column(column_name, df, items_num=None):
    """
    Plot the price distribution for a specified column in a DataFrame using a box plot.
    
    Parameters:
        column_name (str): The name of the column to plot the distribution for.
        df (DataFrame): DataFrame containing the car data.
        items_num (int, optional): The number of top categories to include in the plot. If not specified, all categories will be included.
    
    Returns:
        None
    """
    # Box plot
    plt.figure(figsize=(10, 6))
    
    if items_num is None:
        ax = sns.boxplot(x=column_name, 
                         y='price', 
                         data=df, 
                         order=df.groupby(column_name)['price'].median().sort_values(ascending=False).index)
    else:
        top_categories = df[column_name].value_counts().index.tolist()
        data = df[df[column_name].isin(top_categories)]
        
        ax = sns.boxplot(x=column_name, 
                         y='price', 
                         data=data, 
                         order=data.groupby(column_name)['price'].median().sort_values(ascending=False).head(items_num).index)
    
    plt.title(f'Price Distribution per {column_name.capitalize()}')
    plt.xlabel(column_name.capitalize())
    plt.ylabel('Price')
    
    ax.set_yscale('log')
    plt.show()

# %%
df['region'].value_counts()
# Out:
# region
# columbus                   3608
# jacksonville               3562
# spokane / coeur d'alene    2988
# eugene                     2985
# fresno / madera            2983
#                            ...
# meridian                     28
# southwest MS                 14
# kansas city                  11
# fort smith, AR                9
# west virginia (old)           8
# Name: count, Length: 404, dtype: int64

# %%
# Plot the average price for each category in a specified column
def plot_price_average_per_column(column_name, df, items_num=None):
    """
    Plot the average price for each category in a specified column using a bar plot.
    
    Parameters:
        column_name (str): The name of the column to plot the average price for.
        df (DataFrame): DataFrame containing the car data.
        items_num (int, optional): The number of top categories to include in the plot. If not specified, all categories will be included.
    
    Returns:
        None
    """
    # Bar plot
    plt.figure(figsize=(10, 6))
    
    if items_num is None:
        sns.barplot(x=column_name, 
                    y='price', 
                    data=df, 
                    order=df.groupby(column_name)['price'].mean().sort_values(ascending=False).index)
    else:
        top_categories = df[column_name].value_counts().index.tolist()
        data = df[df[column_name].isin(top_categories)]
        
        sns.barplot(x=column_name, 
                    y='price', 
                    data=data, 
                    order=data.groupby(column_name)['price'].mean().sort_values(ascending=False).head(items_num).index)
    
    plt.title(f'Average Price per {column_name.capitalize()}')
    plt.xlabel(column_name.capitalize())
    plt.ylabel('Price')
    plt.show()

# %% [markdown]
# ### Check columns, column types and null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   region        426880 non-null  object
#  2   price         426880 non-null  int64
#  3   year          425675 non-null  datetime64[ns]
#  4   manufacturer  409234 non-null  object
#  5   model         421603 non-null  object
#  6   condition     252776 non-null  object
#  7   cylinders     249202 non-null  object
#  8   fuel          423867 non-null  object
#  9   odometer      422480 non-null  float64
#  10  title_status  418638 non-null  object
#  11  transmission  424324 non-null  object
#  12  drive         296313 non-null  object
#  13  size          120519 non-null  object
#  14  type          334022 non-null  object
#  15  paint_color   296677 non-null  object
#  16  description   426810 non-null  object
#  17  county        0 non-null       float64
#  18  state         426880 non-null  object
#  19  posting_date  426812 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(15)
# memory usage: 65.1+ MB

# %% [markdown]
# ### Check a sample of rows

# %%
df.sample(20).T
# Out:
#                                                          419799  \
# id                                                   7316356352
# region                                                  madison
# price                                                     27990
# year                                        2012-01-01 00:00:00
# manufacturer                                                gmc
# model                               sierra 2500 hd extended cab
# condition                                                  good
# cylinders                                           8 cylinders
# fuel                                                        gas
# odometer                                                68696.0
# title_status                                              clean
# transmission                                              other
# drive                                                       4wd
# size                                                        NaN
# type                                                     pickup
# paint_color                                               black
# description   Carvana is the safer way to buy a car During t...
# county                                                      NaN
# state                                                        wi
# posting_date                           2021-05-03T14:01:56-0500
#
#                                                          45599   \
# id                                                   7304764049
# region                                             palm springs
# price                                                      9975
# year                                        2010-01-01 00:00:00
# manufacturer                                               audi
# model                                                  a6 3.0 t
# condition                                             excellent
# cylinders                                           6 cylinders
# fuel                                                        gas
# odometer                                               118000.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       4wd
# size                                                  full-size
# type                                                      sedan
# paint_color                                               white
# description   MANAGER'S SPECIAL!!!  *****💰💰💰🤑 >HUGE TAX SALE...
# county                                                      NaN
# state                                                        ca
# posting_date                           2021-04-10T10:31:34-0700
#
#                                                          56983   \
# id                                                   7314892431
# region                                                san diego
# price                                                     29900
# year                                        2017-01-01 00:00:00
# manufacturer                                                bmw
# model                                                        x3
# condition                                                   NaN
# cylinders                                           4 cylinders
# fuel                                                        gas
# odometer                                                21848.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       rwd
# size                                                    compact
# type                                                        SUV
# paint_color                                               black
# description   Most common questions about this vehicle:  Wan...
# county                                                      NaN
# state                                                        ca
# posting_date                           2021-04-30T10:22:40-0700
#
#                                                          164382  \
# id                                                   7316526999
# region                                          kansas city, MO
# price                                                         0
# year                                        1966-01-01 00:00:00
# manufacturer                                                NaN
# model                                                Karminghia
# condition                                                  good
# cylinders                                           4 cylinders
# fuel                                                        gas
# odometer                                                60000.0
# title_status                                              clean
# transmission                                             manual
# drive                                                       rwd
# size                                                    compact
# type                                                      coupe
# paint_color                                              yellow
# description   1966 Karminghia All original! 60,000 miles  Ne...
# county                                                      NaN
# state                                                        ks
# posting_date                           2021-05-03T19:28:42-0500
#
#                                                          272678  \
# id                                                   7314817865
# region                                              long island
# price                                                     15990
# year                                        2015-01-01 00:00:00
# manufacturer                                                bmw
# model                                           i3 hatchback 4d
# condition                                                  good
# cylinders                                                   NaN
# fuel                                                      other
# odometer                                                32091.0
# title_status                                              clean
# transmission                                              other
# drive                                                       rwd
# size                                                        NaN
# type                                                  hatchback
# paint_color                                               white
# description   Carvana is the safer way to buy a car During t...
# county                                                      NaN
# state                                                        ny
# posting_date                           2021-04-30T11:21:44-0400
#
#                                                          37399   \
# id                                                   7314095273
# region                                                  modesto
# price                                                      5999
# year                                        2014-01-01 00:00:00
# manufacturer                                         mitsubishi
# model                                                    lancer
# condition                                             excellent
# cylinders                                                   NaN
# fuel                                                        gas
# odometer                                               151488.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       4wd
# size                                                        NaN
# type                                                      sedan
# paint_color                                                 NaN
# description   2014 *** Mitsubishi Lancer SE AWD 4dr Sedan Se...
# county                                                      NaN
# state                                                        ca
# posting_date                           2021-04-28T16:00:22-0700
#
#                                                          406162  \
# id                                                   7302927552
# region                                               moses lake
# price                                                     17000
# year                                        2014-01-01 00:00:00
# manufacturer                                              honda
# model                                               cr-v lx awd
# condition                                             excellent
# cylinders                                           4 cylinders
# fuel                                                        gas
# odometer                                                87535.0
# title_status                                                NaN
# transmission                                          automatic
# drive                                                       4wd
# size                                                        NaN
# type                                                        SUV
# paint_color                                                 NaN
# description   $199/mo - 2014 Honda CRV CR V CR-V LX AWD87,53...
# county                                                      NaN
# state                                                        wa
# posting_date                           2021-04-06T18:02:58-0700
#
#                                                          215275  \
# id                                                   7315914235
# region                                    minneapolis / st paul
# price                                                     16500
# year                                        2010-01-01 00:00:00
# manufacturer                                          chevrolet
# model                                            silverado 1500
# condition                                             excellent
# cylinders                                           8 cylinders
# fuel                                                        gas
# odometer                                               139000.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       4wd
# size                                                  full-size
# type                                                     pickup
# paint_color                                               white
# description   For Sale, 2010 Heavy Duty half-ton Chev Silver...
# county                                                      NaN
# state                                                        mn
# posting_date                           2021-05-02T15:30:56-0500
#
#                                                          40013   \
# id                                                   7312989590
# region                                             monterey bay
# price                                                     10750
# year                                        2008-01-01 00:00:00
# manufacturer                                              mazda
# model                                                      cx-9
# condition                                             excellent
# cylinders                                                   NaN
# fuel                                                        gas
# odometer                                               157000.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       fwd
# size                                                        NaN
# type                                                        SUV
# paint_color                                              silver
# description   2008 Mazda CX-7- Automatic - Low Miles of 157K...
# county                                                      NaN
# state                                                        ca
# posting_date                           2021-04-26T12:51:59-0700
#
#                                                          86447   \
# id                                                   7314025430
# region                                                new haven
# price                                                     24500
# year                                        2016-01-01 00:00:00
# manufacturer                                               jeep
# model                                                  wrangler
# condition                                             excellent
# cylinders                                           6 cylinders
# fuel                                                        gas
# odometer                                                54000.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       4wd
# size                                                        NaN
# type                                                        NaN
# paint_color                                                grey
# description   2016 Jeep Wrangler for sale   Everyday use car...
# county                                                      NaN
# state                                                        ct
# posting_date                           2021-04-28T16:36:15-0400
#
#                                                          409982  \
# id                                                   7316278333
# region                                    skagit / island / SJI
# price                                                      3500
# year                                        2008-01-01 00:00:00
# manufacturer                                             toyota
# model                                                     prius
# condition                                                  good
# cylinders                                           4 cylinders
# fuel                                                     hybrid
# odometer                                               267300.0
# title_status                                              clean
# transmission                                              other
# drive                                                       fwd
# size                                                   mid-size
# type                                                  hatchback
# paint_color                                               black
# description   This is a high mileage Prius that runs great a...
# county                                                      NaN
# state                                                        wa
# posting_date                           2021-05-03T10:01:49-0700
#
#                                                          91438   \
# id                                                   7311391716
# region                                                 delaware
# price                                                     24990
# year                                        2017-01-01 00:00:00
# manufacturer                                                gmc
# model                                 savana commercial cutaway
# condition                                                  good
# cylinders                                           8 cylinders
# fuel                                                        gas
# odometer                                               136965.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       rwd
# size                                                  full-size
# type                                                      truck
# paint_color                                               white
# description   2017 GMC Savana Commercial Cutaway 3500,, 139"...
# county                                                      NaN
# state                                                        de
# posting_date                           2021-04-23T12:14:52-0400
#
#                                                          171252  \
# id                                                   7314914264
# region                                                lexington
# price                                                      3500
# year                                        2005-01-01 00:00:00
# manufacturer                                          chevrolet
# model                                                    impala
# condition                                                  good
# cylinders                                           6 cylinders
# fuel                                                        gas
# odometer                                               143900.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       fwd
# size                                                   mid-size
# type                                                      sedan
# paint_color                                              custom
# description   2005 Chevy impala with Looks and drives great,...
# county                                                      NaN
# state                                                        ky
# posting_date                           2021-04-30T13:58:32-0400
#
#                                                          6877    \
# id                                                   7307747153
# region                                       anchorage / mat-su
# price                                                     21944
# year                                        2019-01-01 00:00:00
# manufacturer                                          chevrolet
# model                                                    malibu
# condition                                                   NaN
# cylinders                                           4 cylinders
# fuel                                                        gas
# odometer                                                22086.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       fwd
# size                                                        NaN
# type                                                      sedan
# paint_color                                                 red
# description   2019 Chevrolet Malibu 4dr Sdn RS w/1SP -- (907...
# county                                                      NaN
# state                                                        ak
# posting_date                           2021-04-16T08:05:21-0800
#
#                                                          165035  \
# id                                                   7315093415
# region                                          kansas city, MO
# price                                                     24600
# year                                        2008-01-01 00:00:00
# manufacturer                                             toyota
# model                                                    tundra
# condition                                             excellent
# cylinders                                           8 cylinders
# fuel                                                        gas
# odometer                                                48750.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       4wd
# size                                                  full-size
# type                                                      truck
# paint_color                                              custom
# description   2008 Toyota Tundra SR5 Double Cab 5.7L 4WD - $...
# county                                                      NaN
# state                                                        ks
# posting_date                           2021-04-30T18:30:08-0500
#
#                                                          353621  \
# id                                                   7316172348
# region                                                  jackson
# price                                                     20995
# year                                        2019-01-01 00:00:00
# manufacturer                                               ford
# model                                                    fusion
# condition                                                   NaN
# cylinders                                                   NaN
# fuel                                                        gas
# odometer                                                34347.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       NaN
# size                                                        NaN
# type                                                      sedan
# paint_color                                              silver
# description   2019 Ford Fusion SEL     Offered by: James Mot...
# county                                                      NaN
# state                                                        tn
# posting_date                           2021-05-03T09:13:51-0500
#
#                                                          285586  \
# id                                                   7311086538
# region                                            new hampshire
# price                                                      1200
# year                                        2004-01-01 00:00:00
# manufacturer                                              honda
# model                                                     civic
# condition                                                  good
# cylinders                                           4 cylinders
# fuel                                                        gas
# odometer                                               230000.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       NaN
# size                                                        NaN
# type                                                      sedan
# paint_color                                               white
# description   2004 Honda Civic LX  Has new brakes, rotors, c...
# county                                                      NaN
# state                                                        nh
# posting_date                           2021-04-22T18:03:10-0400
#
#                                                          384155  \
# id                                                   7311415797
# region                                                 victoria
# price                                                     32990
# year                                        2015-01-01 00:00:00
# manufacturer                                               ford
# model                                       mustang gt coupe 2d
# condition                                                  good
# cylinders                                           8 cylinders
# fuel                                                        gas
# odometer                                                20832.0
# title_status                                              clean
# transmission                                              other
# drive                                                       rwd
# size                                                        NaN
# type                                                      coupe
# paint_color                                              silver
# description   Carvana is the safer way to buy a car During t...
# county                                                      NaN
# state                                                        tx
# posting_date                           2021-04-23T11:51:06-0500
#
#                                                          99295   \
# id                                                   7311959311
# region                                             jacksonville
# price                                                      9550
# year                                        2015-01-01 00:00:00
# manufacturer                                             toyota
# model                                                   corolla
# condition                                                   NaN
# cylinders                                                   NaN
# fuel                                                        gas
# odometer                                                87021.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       fwd
# size                                                        NaN
# type                                                      sedan
# paint_color                                                 red
# description   2015 Toyota Corolla S Plus 6MT     Offered by:...
# county                                                      NaN
# state                                                        fl
# posting_date                           2021-04-24T13:48:27-0400
#
#                                                          13693
# id                                                   7310049806
# region                                             sierra vista
# price                                                      4500
# year                                        1977-01-01 00:00:00
# manufacturer                                               ford
# model                                                       750
# condition                                                   NaN
# cylinders                                                   NaN
# fuel                                                        gas
# odometer                                               196250.0
# title_status                                              clean
# transmission                                          automatic
# drive                                                       NaN
# size                                                        NaN
# type                                                        NaN
# paint_color                                                 NaN
# description   1977 Ford 750 dump truck $4500 obo in Sierra V...
# county                                                      NaN
# state                                                        az
# posting_date                           2021-04-20T14:32:41-0700

# %% [markdown]
# ### Check number of rows

# %%
# Number of rows in the dataset
len(df)
# Out:
# 426880

# %% [markdown]
# ### Describe numerical columns

# %%
pd.options.display.float_format = "{:.2f}".format

df[["price", "odometer"]].describe()
# Out:
#               price    odometer
# count     426880.00   422480.00
# mean       75199.03    98043.33
# std     12182282.17   213881.50
# min            0.00        0.00
# 25%         5900.00    37704.00
# 50%        13950.00    85548.00
# 75%        26485.75   133542.50
# max   3736928711.00 10000000.00

# %% [markdown]
# **From the above table the price column has a min of 0, max of over 3 and half billion, and a mean of 75 thousand**
# **The odometer on the other hand has a min of 0, max of 10 million miles, and a mean of 98 thousand**

# %% [markdown]
# ### Check null values per column

# %%
# Amount on null values for each column
df.isna().sum()
# Out:
# id                   0
# region               0
# price                0
# year              1205
# manufacturer     17646
# model             5277
# condition       174104
# cylinders       177678
# fuel              3013
# odometer          4400
# title_status      8242
# transmission      2556
# drive           130567
# size            306361
# type             92858
# paint_color     130203
# description         70
# county          426880
# state                0
# posting_date        68
# dtype: int64

# %%
# Check missing data percentage
np.round(df.isnull().sum()/len(df)*100)
# Out:
# id               0.00
# region           0.00
# price            0.00
# year             0.00
# manufacturer     4.00
# model            1.00
# condition       41.00
# cylinders       42.00
# fuel             1.00
# odometer         1.00
# title_status     2.00
# transmission     1.00
# drive           31.00
# size            72.00
# type            22.00
# paint_color     31.00
# description      0.00
# county         100.00
# state            0.00
# posting_date     0.00
# dtype: float64

# %% [markdown]
# As can be seen in the prevouis cell, the county column is entirly empty, so it will be droped

# %% [markdown]
# ### Drop county column

# %%
df.drop("county", axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 19 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   region        426880 non-null  object
#  2   price         426880 non-null  int64
#  3   year          425675 non-null  datetime64[ns]
#  4   manufacturer  409234 non-null  object
#  5   model         421603 non-null  object
#  6   condition     252776 non-null  object
#  7   cylinders     249202 non-null  object
#  8   fuel          423867 non-null  object
#  9   odometer      422480 non-null  float64
#  10  title_status  418638 non-null  object
#  11  transmission  424324 non-null  object
#  12  drive         296313 non-null  object
#  13  size          120519 non-null  object
#  14  type          334022 non-null  object
#  15  paint_color   296677 non-null  object
#  16  description   426810 non-null  object
#  17  state         426880 non-null  object
#  18  posting_date  426812 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(15)
# memory usage: 61.9+ MB

# %% [markdown]
# ### Check the date columns types

# %%
df['posting_date'].dtype, df['year'].dtype
# Out:
# (dtype('O'), dtype('<M8[ns]'))

# %% [markdown]
# ### Check the `posting_date` column format

# %%
df['posting_date']
# Out:
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#                     ...
# 426875    2021-04-04T03:21:31-0600
# 426876    2021-04-04T03:21:29-0600
# 426877    2021-04-04T03:21:17-0600
# 426878    2021-04-04T03:21:11-0600
# 426879    2021-04-04T03:21:07-0600
# Name: posting_date, Length: 426880, dtype: object

# %% [markdown]
# ### Transform `posting_date` to datetime and remove last 5 characters

# %%
df['posting_date'] = pd.to_datetime(df['posting_date'].str[:-6], format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# ### Check a sample of rows

# %%
df.sample(40)
# Out:
#                 id                  region  price       year   manufacturer  \
# 362718  7311593845                 abilene  38888 2018-01-01           ford
# 397349  7306436483                richmond   4200 2006-01-01           ford
# 187638  7314239233                  boston      0 2012-01-01           audi
# 62679   7316290214             SF bay area      0 2016-01-01         nissan
# 292859  7313725853               cleveland   4000 2005-01-01           ford
# 227308  7311860839                  helena   8000 1995-01-01         subaru
# 132904  7313417307                   boise      0 2015-01-01           ford
# 177438  7311252455              shreveport  31990 2017-01-01           ford
# 363412  7302352952                amarillo  15900 2015-01-01      chevrolet
# 93181   7306185348           daytona beach  20990 2019-01-01        hyundai
# 54962   7316381718               san diego      0 2017-01-01           ford
# 372494  7311341006                 el paso   8950 2010-01-01            bmw
# 235149  7308241457              eastern NC   6800 2004-01-01           ford
# 193243  7305317942  worcester / central MA   9500 1931-01-01           ford
# 159506  7315832814              fort dodge   8499 1995-01-01           ford
# 361121  7311043595               nashville  26574 2013-01-01            gmc
# 131075  7316246438                   boise      0 2015-01-01         nissan
# 258841  7303809947            south jersey   5990 2015-01-01      chevrolet
# 344813  7304841307              charleston      0 2015-01-01           ford
# 287427  7309530790          akron / canton  24900 2001-01-01      chevrolet
# 41919   7315717228           orange county  19777 2019-01-01          honda
# 127038  7303634769   savannah / hinesville   8570 2009-01-01           jeep
# 13894   7316808825                  tucson   2900 1999-01-01          honda
# 226174  7306629883                 bozeman  18900 2016-01-01      chevrolet
# 289660  7314819581              cincinnati   4500 1987-01-01  mercedes-benz
# 89722   7314773797          washington, DC   6900 2001-01-01         toyota
# 170786  7315105421        eastern kentucky      0 2014-01-01            ram
# 264443  7311435518                  albany  27990 2008-01-01           ford
# 101080  7313567436                lakeland  55000 2013-01-01            NaN
# 42525   7315022612           orange county  30000 2016-01-01            ram
# 359208  7315444709               nashville  24990 2013-01-01            gmc
# 419905  7315487493                 madison  14500 2009-01-01            gmc
# 425911  7309871917                  wausau  28900 2020-01-01       chrysler
# 193479  7303195439  worcester / central MA   5995 2005-01-01         nissan
# 25088   7303300133                   chico   1800 1970-01-01     volkswagen
# 273834  7311526147             long island    289 2014-01-01            ram
# 95025   7312443666   ft myers / SW florida  32990 2016-01-01           jeep
# 340508  7316249592            williamsport   4300 2001-01-01          honda
# 174683  7313872914             baton rouge  12990 2008-01-01            gmc
# 154710  7311556662   south bend / michiana   4800 1997-01-01          dodge
#
#                                 model  condition    cylinders    fuel  \
# 362718                       f250 4x4        NaN          NaN     gas
# 397349                  escape hybrid  excellent  4 cylinders  hybrid
# 187638    a4 allroad premium plus awd   like new  4 cylinders     gas
# 62679                        frontier       good          NaN     gas
# 292859                           f150        NaN          NaN     gas
# 227308                         legacy   like new  4 cylinders     gas
# 132904                        mustang        NaN          NaN     gas
# 177438            mustang gt coupe 2d       good  8 cylinders     gas
# 363412                       traverse  excellent  6 cylinders     gas
# 93181             sonata sel sedan 4d       good          NaN     gas
# 54962                            edge  excellent          NaN     gas
# 372494                   x3 sdrive30i   like new  6 cylinders     gas
# 235149                           f150       good  8 cylinders     gas
# 193243                            NaN       fair  4 cylinders     gas
# 159506                          f-150       good  8 cylinders     gas
# 361121                         sierra        NaN          NaN   other
# 131075                          rogue        NaN          NaN     gas
# 258841                          cruze  excellent  4 cylinders     gas
# 344813                         f59 18        NaN          NaN     gas
# 287427                       corvette        NaN  8 cylinders     gas
# 41919                     civic sedan        NaN          NaN     gas
# 127038                 grand cherokee        NaN  8 cylinders     gas
# 13894                             crv  excellent          NaN     gas
# 226174                       colorado  excellent          NaN     gas
# 289660                    benz 300sdl       good  6 cylinders  diesel
# 89722                          tacoma        NaN  6 cylinders     gas
# 170786                            NaN        NaN          NaN  diesel
# 264443            econoline cargo van       good  8 cylinders     gas
# 101080  freightliner cascadia sleeper       good          NaN  diesel
# 42525                             NaN  excellent          NaN     gas
# 359208   sierra 1500 extended cab slt       good  8 cylinders     gas
# 419905                   yukon hybrid  excellent  8 cylinders  hybrid
# 425911             pacifica touring l       good  6 cylinders     gas
# 193479                         xterra   like new          NaN     gas
# 25088                          type 3        NaN          NaN     gas
# 273834                           1500        NaN          NaN     gas
# 95025          wrangler rubicon sport       good  6 cylinders     gas
# 340508                       civic ex       good  4 cylinders     gas
# 174683                    sierra 1500        NaN          NaN     gas
# 154710                     dakota slt  excellent  8 cylinders     gas
#
#         odometer title_status transmission drive       size    type  \
# 362718  88310.00        clean    automatic   NaN        NaN     NaN
# 397349 169938.00        clean    automatic   4wd   mid-size     SUV
# 187638    140.00        clean    automatic   4wd   mid-size   wagon
# 62679   51501.00        clean    automatic   NaN        NaN  pickup
# 292859 201000.00        clean    automatic   NaN        NaN     NaN
# 227308  24000.00        clean    automatic   4wd  full-size   wagon
# 132904  14238.00        clean        other   NaN        NaN     NaN
# 177438  19043.00        clean    automatic   rwd        NaN   coupe
# 363412  86479.00        clean    automatic   fwd        NaN     SUV
# 93181   22776.00        clean        other   fwd        NaN   sedan
# 54962   49373.00        clean    automatic   NaN        NaN     SUV
# 372494 119040.00        clean    automatic   4wd  full-size     SUV
# 235149 240000.00        clean    automatic   4wd  full-size   truck
# 193243  99999.00        clean       manual   NaN        NaN     NaN
# 159506 115223.00        clean    automatic   fwd  full-size  pickup
# 361121  90616.00        clean    automatic   4wd        NaN  pickup
# 131075  98075.00        clean    automatic   NaN        NaN     NaN
# 258841 113000.00        clean    automatic   fwd   mid-size   sedan
# 344813       NaN        clean          NaN   NaN        NaN   other
# 287427  72970.00        clean       manual   rwd        NaN   coupe
# 41919   18691.00        clean    automatic   fwd        NaN     NaN
# 127038 188832.00        clean    automatic   4wd        NaN     SUV
# 13894   68000.00        clean    automatic   NaN        NaN     SUV
# 226174 155335.00        clean    automatic   4wd        NaN     NaN
# 289660 265000.00        clean    automatic   rwd  full-size   sedan
# 89722  224807.00        clean    automatic   rwd        NaN  pickup
# 170786      0.00        clean    automatic   NaN        NaN   other
# 264443  83459.00        clean    automatic   rwd  full-size   truck
# 101080 500000.00        clean       manual   NaN        NaN     NaN
# 42525   77108.00        clean    automatic   NaN        NaN     NaN
# 359208  94891.00        clean        other   4wd        NaN  pickup
# 419905 151000.00        clean    automatic   4wd  full-size     SUV
# 425911  36222.00        clean    automatic   fwd        NaN     NaN
# 193479    180.00        clean    automatic   4wd        NaN     NaN
# 25088   99999.00        clean       manual   NaN        NaN     NaN
# 273834 132728.00        clean    automatic   4wd        NaN  pickup
# 95025   42344.00        clean        other   4wd        NaN   other
# 340508 136000.00        clean    automatic   fwd   mid-size   sedan
# 174683 159325.00        clean    automatic   NaN        NaN   other
# 154710 192000.00        clean    automatic   rwd   mid-size  pickup
#
#        paint_color                                        description state  \
# 362718         NaN  CALL OR TEXT 512-914-8066  www.GETADIESEL.com ...    tx
# 397349      silver  Very well maintained, Super clean It is in a g...    va
# 187638        blue  Topline Import Methuen 1030 Riverside Drive Me...    ma
# 62679       silver  Call Us For A Test Drive!Call (or text) ☏ (707...    ca
# 292859         NaN  Sign my 2005  Ford F150 4×4 for  4000 or best ...    oh
# 227308      silver  USD $8,000 STOCK IN CANADA + $100 DOC Fee 1995...    mt
# 132904         NaN  Bluetooth Back Up Camera Dual Power Seats Powe...    id
# 177438      silver  Carvana is the safer way to buy a car During t...    la
# 363412       white  2015 *** CHEVROLET TRAVERSE LTZ SUV ***    Rea...    tx
# 93181         blue  Carvana is the safer way to buy a car During t...    fl
# 54962          NaN  East County Pre-Owned Superstore provides a 10...    ca
# 372494      silver  2010 BMW XDrive X3 3.0SI All-Wheel Drive (AWD)...    tx
# 235149       white  04 f150 5.4 3v runs good previous owner put re...    nc
# 193243         NaN  Just out of a barn.  Yard runs.  If you want a...    ma
# 159506       white  I have this truck is n good condition I done A...    ia
# 361121       black  2013 GMC Sierra 1500 4WD Ext Cab 143.5" SLT   ...    tn
# 131075         NaN  Power Mirrors Bluetooth Anti-Theft Keyless Ent...    id
# 258841         red  Call or text: Eightfivesix 379 sevenfour 33  2...    nj
# 344813         NaN  2015 Ford F59 18 Food Truck, Catering Truck, T...    sc
# 287427       black  2001 Chevrolet Corvette Z06 Hardtop V8 Clean C...    oh
# 41919        white  Premier Chevrolet of Buena Park address:    61...    ca
# 127038      silver  2009 *Jeep* *Grand Cherokee* 4WD 4dr Overland ...    ga
# 13894          NaN  $2,900 or best offer   Changed engine at 190,0...    az
# 226174         NaN  2016 Chevrolet Colorado 4WD Z71    Ready To Up...    mt
# 289660      yellow  1987 Mercedes Benz 300SDL in very good conditi...    oh
# 89722       silver  2001 *Toyota* *Tacoma* DoubleCab PreRunner V6 ...    dc
# 170786       white  All Trucks USA12106 Old River RdRockton, IL 61...    ky
# 264443       white  2008 Ford Econoline Cargo Van E-350 CARGO, BUC...    ny
# 101080       white  Engine\tDetroit Model\tDD 15 Horsepower\t455 T...    fl
# 42525          NaN  2016 Dodge Ram 2500 W/ Utility Bed 77,108 Mile...    ca
# 359208         NaN  Carvana is the safer way to buy a car During t...    tn
# 419905       black  Beautiful Hybrid V8 2009 GMC Yukon runs and dr...    wi
# 425911      silver  One Owner, Non Smoker, No Accidents, Power Sli...    wi
# 193479         NaN  Nissan Xterra Off Road edition  SUV tow packag...    ma
# 25088          NaN  4/70 VW Fastback no motor or bumpers- ALL seat...    ca
# 273834         NaN  2014 Ram 1500 4WD Crew Cab 149' Big Horn 289  ...    ny
# 95025       silver  Carvana is the safer way to buy a car During t...    fl
# 340508        blue  *136,000 MILES *AUTOMATIC *4CYL VTEC 1.7L *ABS...    pa
# 174683         NaN  2008 GMC Sierra 1500 CREW CAB PICKUP 4-DR     ...    la
# 154710       white  1997 Dodge Dakota SLT Sport 5.2 Liter V-8 Auto...    in
#
#               posting_date
# 362718 2021-04-23 16:42:04
# 397349 2021-04-13 19:07:03
# 187638 2021-04-29 07:56:01
# 62679  2021-05-03 10:19:05
# 292859 2021-04-28 05:26:00
# 227308 2021-04-24 09:12:01
# 132904 2021-04-27 11:36:03
# 177438 2021-04-23 06:01:02
# 363412 2021-04-05 18:00:01
# 93181  2021-04-13 12:01:01
# 54962  2021-05-03 12:43:00
# 372494 2021-04-23 08:54:01
# 235149 2021-04-17 11:07:00
# 193243 2021-04-11 16:16:01
# 159506 2021-05-02 12:53:03
# 361121 2021-04-22 15:41:00
# 131075 2021-05-03 10:14:02
# 258841 2021-04-08 15:31:05
# 344813 2021-04-10 15:32:02
# 287427 2021-04-19 18:23:02
# 41919  2021-05-02 06:47:04
# 127038 2021-04-08 11:01:00
# 13894  2021-05-04 10:22:00
# 226174 2021-04-14 08:00:05
# 289660 2021-04-30 11:24:05
# 89722  2021-04-30 10:00:05
# 170786 2021-04-30 20:00:03
# 264443 2021-04-23 13:20:04
# 101080 2021-04-27 17:57:03
# 42525  2021-04-30 14:03:01
# 359208 2021-05-01 14:11:00
# 419905 2021-05-01 15:29:01
# 425911 2021-04-20 11:45:02
# 193479 2021-04-07 13:08:05
# 25088  2021-04-07 12:54:00
# 273834 2021-04-23 15:43:01
# 95025  2021-04-25 14:41:02
# 340508 2021-05-03 12:19:00
# 174683 2021-04-28 11:24:02
# 154710 2021-04-23 16:35:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 19 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   region        426880 non-null  object
#  2   price         426880 non-null  int64
#  3   year          425675 non-null  datetime64[ns]
#  4   manufacturer  409234 non-null  object
#  5   model         421603 non-null  object
#  6   condition     252776 non-null  object
#  7   cylinders     249202 non-null  object
#  8   fuel          423867 non-null  object
#  9   odometer      422480 non-null  float64
#  10  title_status  418638 non-null  object
#  11  transmission  424324 non-null  object
#  12  drive         296313 non-null  object
#  13  size          120519 non-null  object
#  14  type          334022 non-null  object
#  15  paint_color   296677 non-null  object
#  16  description   426810 non-null  object
#  17  state         426880 non-null  object
#  18  posting_date  426812 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(14)
# memory usage: 61.9+ MB

# %% [markdown]
# ### Create a copy of dataframe

# %%
df_temp = df.copy()

# %%
df_temp
# Out:
#                 id                  region  price       year manufacturer  \
# 0       7222695916                prescott   6000        NaT          NaN
# 1       7218891961            fayetteville  11900        NaT          NaN
# 2       7221797935            florida keys  21000        NaT          NaN
# 3       7222270760  worcester / central MA   1500        NaT          NaN
# 4       7210384030              greensboro   4900        NaT          NaN
# ...            ...                     ...    ...        ...          ...
# 426875  7301591192                 wyoming  23590 2019-01-01       nissan
# 426876  7301591187                 wyoming  30590 2020-01-01        volvo
# 426877  7301591147                 wyoming  34990 2020-01-01     cadillac
# 426878  7301591140                 wyoming  28990 2018-01-01        lexus
# 426879  7301591129                 wyoming  30590 2019-01-01          bmw
#
#                            model condition    cylinders    fuel  odometer  \
# 0                            NaN       NaN          NaN     NaN       NaN
# 1                            NaN       NaN          NaN     NaN       NaN
# 2                            NaN       NaN          NaN     NaN       NaN
# 3                            NaN       NaN          NaN     NaN       NaN
# 4                            NaN       NaN          NaN     NaN       NaN
# ...                          ...       ...          ...     ...       ...
# 426875         maxima s sedan 4d      good  6 cylinders     gas  32226.00
# 426876  s60 t5 momentum sedan 4d      good          NaN     gas  12029.00
# 426877          xt4 sport suv 4d      good          NaN  diesel   4174.00
# 426878           es 350 sedan 4d      good  6 cylinders     gas  30112.00
# 426879  4 series 430i gran coupe      good          NaN     gas  22716.00
#
#        title_status transmission drive size       type paint_color  \
# 0               NaN          NaN   NaN  NaN        NaN         NaN
# 1               NaN          NaN   NaN  NaN        NaN         NaN
# 2               NaN          NaN   NaN  NaN        NaN         NaN
# 3               NaN          NaN   NaN  NaN        NaN         NaN
# 4               NaN          NaN   NaN  NaN        NaN         NaN
# ...             ...          ...   ...  ...        ...         ...
# 426875        clean        other   fwd  NaN      sedan         NaN
# 426876        clean        other   fwd  NaN      sedan         red
# 426877        clean        other   NaN  NaN  hatchback       white
# 426878        clean        other   fwd  NaN      sedan      silver
# 426879        clean        other   rwd  NaN      coupe         NaN
#
#                                               description state  \
# 0                                                     NaN    az
# 1                                                     NaN    ar
# 2                                                     NaN    fl
# 3                                                     NaN    ma
# 4                                                     NaN    nc
# ...                                                   ...   ...
# 426875  Carvana is the safer way to buy a car During t...    wy
# 426876  Carvana is the safer way to buy a car During t...    wy
# 426877  Carvana is the safer way to buy a car During t...    wy
# 426878  Carvana is the safer way to buy a car During t...    wy
# 426879  Carvana is the safer way to buy a car During t...    wy
#
#               posting_date
# 0                      NaT
# 1                      NaT
# 2                      NaT
# 3                      NaT
# 4                      NaT
# ...                    ...
# 426875 2021-04-04 03:21:03
# 426876 2021-04-04 03:21:02
# 426877 2021-04-04 03:21:01
# 426878 2021-04-04 03:21:01
# 426879 2021-04-04 03:21:00
#
# [426880 rows x 19 columns]

# %% [markdown]
# ### Visualize price vs year

# %%
plt.style.use('seaborn-v0_8')
plt.rcParams["font.size"] = 50
plt.rcParams["xtick.labelsize"] = 10

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax.scatter(df_temp['year'], df['price']);
ax.set_yscale('log')

# Customize the plot
ax.set(title="Car Price vs Manufacture Year", xlabel="Year", ylabel='Price in $');

# %% [markdown]
# ### Visulize price vs posting_date

# %%
df_temp["posting_year"] = df_temp.posting_date.dt.year
fig, ax = plt.subplots(figsize=(12, 8))
ax.scatter(df_temp['posting_year'], df['price']);
ax.set_yscale('log')

# Customize the plot
ax.set(title="Car Price vs Posting Year", xlabel="Posting Year", ylabel='Price in $');
# Set the limits for the x-axis to zoom in (e.g., 1990 to 2025)
ax.set_xlim(2018, 2024);

# %% [markdown]
# **The `posting_date` column has only one year and that is 2021**

# %%
# df_temp["posting_year"] = df_temp.posting_date.dt.year
# df_temp["posting_month"] = df_temp.posting_date.dt.month
# df_temp["posting_day"] = df_temp.posting_date.dt.day
# df_temp["posting_day_of_week"] = df_temp.posting_date.dt.dayofweek

# df["posting_year"] = df.posting_date.dt.year.astype(int)
# df["posting_month"] = df.posting_date.dt.month.astype(int)
# df["posting_day"] = df.posting_date.dt.day.astype(int)
# df["posting_day_of_week"] = df.posting_date.dt.dayofweek.astype(int)

# %%
# fig, ax = plt.subplots(figsize=(12, 8))
# ax.scatter(df_temp['posting_year'], df['price']);
# ax.set_yscale('log')

# # Customize the plot
# ax.set(title="Car Price vs Manufacture Year", xlabel="Year", ylabel='Price in $');

# %% [markdown]
# ### Visualize price distribution

# %%
# Plot price distripution
fig, ax = plt.subplots(figsize=(10, 6));
hist = ax.hist(df['price'], bins=6);
plt.ticklabel_format(style = 'plain')

# Customize the plot
ax.set(title="Price Distribution (Frequency of the Prices)", xlabel="Price in $", ylabel='Frequency');
ax.set_yscale('log');

# %% [markdown]
# ### Visualize price outliers

# %% [markdown]
# **The figure above shows that most prices are between 0 and 500,000,000. There are some extreme outliers present in the `price` column.**

# %%
visualize_distribution(df, "price", "the price (Log scale)")

# %% [markdown]
# **As suspected, there are many extreme outliers in the `price` column (target).**

# %%
# More visualization to do

# Odometer vs Price
# Fuel vs Price
# All vs Price

# Number of cars per Region (Bar)
# Number of cars per State
# Number of cars per Manufa
# Number of cars per Model
# Number of cars per Drive
# Number of cars per Trans
# Number of cars per Type
# Number of cars per Condition
# Number of cars per Cylinder
# Number of cars for each Fuel type (Bar, Pie)
# Number of cars per Size

# Something with Color

# %% [markdown]
# ### Get a sample of the data

# %%
df_temp.sample(10).T
# Out:
#                                                          368462  \
# id                                                   7303093148
# region                                           corpus christi
# price                                                      6995
# year                                        2006-01-01 00:00:00
# manufacturer                                              mazda
# model                                                   tribute
# condition                                             excellent
# cylinders                                           6 cylinders
# fuel                                                        gas
# odometer                                              126929.00
# title_status                                              clean
# transmission                                          automatic
# drive                                                       fwd
# size                                                        NaN
# type                                                        NaN
# paint_color                                                 NaN
# description   2006 Mazda Tribute 3.0L Auto s    Ready To Upg...
# state                                                        tx
# posting_date                                2021-04-07 09:30:04
# posting_year                                            2021.00
#
#                                                          253749  \
# id                                                   7315570032
# region                                             north jersey
# price                                                     18495
# year                                        2012-01-01 00:00:00
# manufacturer                                            porsche
# model                                                   cayenne
# condition                                                   NaN
# cylinders                                                   NaN
# fuel                                                        gas
# odometer                                              143471.00
# title_status                                              clean
# transmission                                                NaN
# drive                                                       NaN
# size                                                        NaN
# type                                                        SUV
# paint_color                                               white
# description   2012 Porsche Cayenne S AWD S 4dr SUV     Offer...
# state                                                        nj
# posting_date                                2021-05-01 19:35:03
# posting_year                                            2021.00
#
#                                                          320766  \
# id                                                   7303261321
# region                                          medford-ashland
# price                                                     16995
# year                                        2019-01-01 00:00:00
# manufacturer                                             toyota
# model                                      corolla le 4dr sedan
# condition                                                   NaN
# cylinders                                                   NaN
# fuel                                                        gas
# odometer                                               53787.00
# title_status                                              clean
# transmission                                          automatic
# drive                                                       NaN
# size                                                        NaN
# type                                                        NaN
# paint_color                                                 NaN
# description   2019 Black Toyota Corolla LE 4dr Sedan  Sellin...
# state                                                        or
# posting_date                                2021-04-07 11:49:02
# posting_year                                            2021.00
#
#                                                          187458  \
# id                                                   7314451503
# region                                                   boston
# price                                                     11995
# year                                        2012-01-01 00:00:00
# manufacturer                                             nissan
# model                                         xterra pro-4x 4wd
# condition                                                   NaN
# cylinders                                           6 cylinders
# fuel                                                        gas
# odometer                                              174702.00
# title_status                                              clean
# transmission                                          automatic
# drive                                                       4wd
# size                                                        NaN
# type                                                        SUV
# paint_color                                                grey
# description   TOP NOTCH AUTO AND TRUCK SALES IS PLEASED TO O...
# state                                                        ma
# posting_date                                2021-04-29 14:55:04
# posting_year                                            2021.00
#
#                                                          122161  \
# id                                                   7316144846
# region                                                  atlanta
# price                                                     18500
# year                                        2013-01-01 00:00:00
# manufacturer                                               audi
# model                                   a7 quattro supercharged
# condition                                              like new
# cylinders                                           6 cylinders
# fuel                                                        gas
# odometer                                              108000.00
# title_status                                              clean
# transmission                                          automatic
# drive                                                       4wd
# size                                                  full-size
# type                                                  hatchback
# paint_color                                               black
# description   ((REDUCED PRICE From 19500 to 18500)) 2013 Aud...
# state                                                        ga
# posting_date                                2021-05-03 09:18:02
# posting_year                                            2021.00
#
#                                                          94346   \
# id                                                   7315076020
# region                                    ft myers / SW florida
# price                                                      6300
# year                                        2012-01-01 00:00:00
# manufacturer                                              honda
# model                                                     civic
# condition                                                   NaN
# cylinders                                                   NaN
# fuel                                                        gas
# odometer                                              158300.00
# title_status                                              clean
# transmission                                          automatic
# drive                                                       NaN
# size                                                        NaN
# type                                                        NaN
# paint_color                                                 NaN
# description   2012 Honda Civic; Clean title, cold ac, like n...
# state                                                        fl
# posting_date                                2021-04-30 18:50:04
# posting_year                                            2021.00
#
#                                                          71866   \
# id                                                   7315444704
# region                                                  boulder
# price                                                     19990
# year                                        2017-01-01 00:00:00
# manufacturer                                             subaru
# model                                      impreza 2.0i limited
# condition                                                  good
# cylinders                                                   NaN
# fuel                                                        gas
# odometer                                               19306.00
# title_status                                              clean
# transmission                                              other
# drive                                                       NaN
# size                                                        NaN
# type                                                      sedan
# paint_color                                                blue
# description   Carvana is the safer way to buy a car During t...
# state                                                        co
# posting_date                                2021-05-01 13:11:00
# posting_year                                            2021.00
#
#                                                          607     \
# id                                                   7313012435
# region                                               birmingham
# price                                                         0
# year                                        2010-01-01 00:00:00
# manufacturer                                          chevrolet
# model                                                    cobalt
# condition                                                   NaN
# cylinders                                           4 cylinders
# fuel                                                        gas
# odometer                                              162455.00
# title_status                                              clean
# transmission                                          automatic
# drive                                                       fwd
# size                                                        NaN
# type                                                      sedan
# paint_color                                                 NaN
# description   2010 *Chevrolet* *Cobalt* 4dr Sedan LT w/2LTCa...
# state                                                        al
# posting_date                                2021-04-26 15:30:03
# posting_year                                            2021.00
#
#                                                          179265  \
# id                                                   7311802379
# region                                                    maine
# price                                                     39990
# year                                        2019-01-01 00:00:00
# manufacturer                                               ford
# model                                                     f-150
# condition                                                   NaN
# cylinders                                                   NaN
# fuel                                                        gas
# odometer                                               18838.00
# title_status                                              clean
# transmission                                                NaN
# drive                                                       4wd
# size                                                        NaN
# type                                                     pickup
# paint_color                                                 NaN
# description   2019 Ford F-150 F150 F 150     Offered by: DIE...
# state                                                        me
# posting_date                                2021-04-24 09:13:01
# posting_year                                            2021.00
#
#                                                          342675
# id                                                   7311316472
# region                                             rhode island
# price                                                     31590
# year                                        2019-01-01 00:00:00
# manufacturer                                             toyota
# model                                    86 trd special edition
# condition                                                  good
# cylinders                                                   NaN
# fuel                                                      other
# odometer                                                2207.00
# title_status                                              clean
# transmission                                              other
# drive                                                       NaN
# size                                                        NaN
# type                                                      coupe
# paint_color                                               black
# description   Carvana is the safer way to buy a car During t...
# state                                                        ri
# posting_date                                2021-04-23 10:11:00
# posting_year                                            2021.00

# %% [markdown]
# ### Visualize Region

# %%
cars_per_region = df_temp['region'].value_counts()
cars_per_region
# Out:
# region
# columbus                   3608
# jacksonville               3562
# spokane / coeur d'alene    2988
# eugene                     2985
# fresno / madera            2983
#                            ...
# meridian                     28
# southwest MS                 14
# kansas city                  11
# fort smith, AR                9
# west virginia (old)           8
# Name: count, Length: 404, dtype: int64

# %% [markdown]
# #### Number of cars per region

# %%
plot_column_frequancy("region", df_temp, 5)

# %% [markdown]
# **Columbus, Jacksonville, Spokane/coeur d'alene, Eugene and Fresno/madera are the top 5 regions with the most cars for sale. They each have 3600, 3500, 3000, 3000, 3000 cars offered for sale, respectively.**

# %% [markdown]
# #### Price distribution per region / top 5

# %%
plot_price_distribution_per_column("region", df_temp, 5)

# %%
calculate_price_quartiles_by_column("region", df_temp, 5)
# Out:
# Below are the Q1, Q2 (median), & Q3 values:
# Q1 (First Quartile): represents the lower quartile, 25% of the data points are less than or equal to Q1
# Q2 (Median): represents the middle quartile, dividing the dataset into two equal parts
# Q3 (Third Quartile): represents the upper quartile, 75% of the data points are less than or equal to Q3
#
# Price distribution per region:
# Logan: Q1: 17712.25, Median: 34999.0, Q3: 44248.0
# Olympic peninsula: Q1: 19999.0, Median: 32999.0, Q3: 42999.0
# Scottsbluff / panhandle: Q1: 19337.0, Median: 32900.0, Q3: 43900.0
# Butte: Q1: 12991.25, Median: 32677.5, Q3: 41999.0
# East oregon: Q1: 12943.25, Median: 31410.0, Q3: 44999.0

# %% [markdown]
# #### Price average per region / top 5

# %%
plot_price_average_per_column("region", df_temp, 5)

# %%
calculate_average_price_by_column("region", df_temp, 5)
# Out:
# Below are the average prices per region values:
# Frederick: $4914334.20
# Delaware: $3205055.89
# Humboldt county: $2902729.97
# Modesto: $1401324.30
# Knoxville: $1369993.30

# %% [markdown]
# ### Visualize State

# %% [markdown]
# #### 1. Number of cars per state

# %%
cars_per_state = df_temp['state'].value_counts()
cars_per_state
# Out:
# state
# ca    50614
# fl    28511
# tx    22945
# ny    19386
# oh    17696
# or    17104
# mi    16900
# nc    15277
# wa    13861
# pa    13753
# wi    11398
# co    11088
# tn    11066
# va    10732
# il    10387
# nj     9742
# id     8961
# az     8679
# ia     8632
# ma     8174
# mn     7716
# ga     7003
# ok     6792
# sc     6327
# mt     6294
# ks     6209
# in     5704
# ct     5188
# al     4955
# md     4778
# nm     4425
# mo     4293
# ky     4149
# ar     4038
# ak     3474
# la     3196
# nv     3194
# nh     2981
# dc     2970
# me     2966
# hi     2964
# vt     2513
# ri     2320
# sd     1302
# ut     1150
# wv     1052
# ne     1036
# ms     1016
# de      949
# wy      610
# nd      410
# Name: count, dtype: int64

# %%
plot_column_frequancy("state", df_temp, 5)

# %% [markdown]
# **California, Florida, Texas, New York, and Ohio are the top 5 states with the most cars for sale. They each have 50000, 28000, 23000, 20000, 17000 cars offered for sale, respectively.**

# %% [markdown]
# ### Visualize Manufacturer

# %% [markdown]
# #### 1. Number of cars per Manufacturer

# %%
cars_per_manufacturer = df_temp['manufacturer'].value_counts()
cars_per_manufacturer
# Out:
# manufacturer
# ford               70985
# chevrolet          55064
# toyota             34202
# honda              21269
# nissan             19067
# jeep               19014
# ram                18342
# gmc                16785
# bmw                14699
# dodge              13707
# mercedes-benz      11817
# hyundai            10338
# subaru              9495
# volkswagen          9345
# kia                 8457
# lexus               8200
# audi                7573
# cadillac            6953
# chrysler            6031
# acura               5978
# buick               5501
# mazda               5427
# infiniti            4802
# lincoln             4220
# volvo               3374
# mitsubishi          3292
# mini                2376
# pontiac             2288
# rover               2113
# jaguar              1946
# porsche             1384
# mercury             1184
# saturn              1090
# alfa-romeo           897
# tesla                868
# fiat                 792
# harley-davidson      153
# ferrari               95
# datsun                63
# aston-martin          24
# land rover            21
# morgan                 3
# Name: count, dtype: int64

# %%
colors = plt.cm.tab20c(np.arange(len(cars_per_manufacturer)))

# Sort data by value
data_sorted = cars_per_manufacturer.sort_values(ascending=False)

# Extract labels and values
labels = data_sorted.index.tolist()
values = data_sorted.values.tolist()

# Group small categories into 'Other'
threshold = 0.05  # Adjust as needed
total = sum(values)
other_value = sum([value for value in values if value / total < threshold])
other_label = 'Other'
labels = labels[:11] + [other_label]
values = values[:11] + [other_value]

# Create pie chart
fig, ax = plt.subplots(figsize=(10, 10))
ax.pie(values, labels=labels, autopct='%1.1f%%', startangle=90, textprops={'fontsize': 10}, colors=colors)

# Equal aspect ratio ensures that pie is drawn as a circle
ax.axis('equal')

# Set title
ax.set_title("Used Cars per Manufacturer")

plt.show()

# %% [markdown]
# **Ford, Chevrolet, and Toyota have the highest number of cars.**

# %% [markdown]
# ### Model

# %% [markdown]
# #### 1. Number of cars per model

# %%
combined_model_manufacturer = df_temp.copy()
combined_model_manufacturer["model_manufacturer"] = df_temp["manufacturer"] + " " + df_temp["model"]

cars_per_model = combined_model_manufacturer["model_manufacturer"].value_counts()
cars_per_model
# Out:
# model_manufacturer
# ford f-150                  8009
# chevrolet silverado 1500    5140
# ram 1500                    4069
# toyota camry                3133
# chevrolet silverado         3021
#                             ...
# mitsubishi eclipse gs-t        1
# ram 1500 hemi crew             1
# ford xlt x-cab                 1
# ford f150 fx/2 sport           1
# jeep gand wagoneer             1
# Name: count, Length: 24169, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 6));
bar = ax.bar(cars_per_model.index.tolist()[:5], cars_per_model.iloc[:5]);

# Customize the bar
ax.set(title="Used Cars per Manufacturer & Model / Top 5", xlabel="Model", ylabel='Number of Cars');

# %% [markdown]
# **Ford f-150 is the most common car model with 8000 cars for sale, followed by Chevrolet silverado 1500 with over 5000 cars and Ram 1500 with over 4000 cars.**

# %% [markdown]
# #### 2. Get unique models

# %%
unique_models = df_temp["model"].unique()

# Print all unique values one by one
# for model in unique_models:
#     print(model)

# %% [markdown]
# #### 3. Number of Ford cars models

# %%
ford_records = df_temp[df_temp['manufacturer'] == "ford"]
ford_models = ford_records["model"].value_counts()
ford_models
# Out:
# model
# f-150                                        8009
# escape                                       2745
# explorer                                     2499
# mustang                                      2220
# fusion                                       1979
#                                              ...
# f-150 crew cab limited                          1
# f-550 service truck under deck compressor       1
# runabout roadster                               1
# f150 fx-2 sport                                 1
# f150, platinum                                  1
# Name: count, Length: 3874, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 6));
bar = ax.bar(ford_models.index.tolist()[:5], ford_models.iloc[:5]);

# Customize the bar
ax.set(title="Used Ford Cars / Top 5 Models", xlabel="Ford Model", ylabel='Number of Cars');

# %% [markdown]
# **The top used Ford cars are f-150, escape, explorer, mustang and fusion.**

# %% [markdown]
# ### Visualize Odometer

# %% [markdown]
# #### 1. Car price vs odometer

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax.scatter(df_temp['odometer'], df_temp['price']);
plt.ticklabel_format(style = 'plain')

# Customize the plot
ax.set(title="Car Price vs Odometer", xlabel="Odometer in Miles", ylabel='Price in $');
ax.set_yscale('log')

# %% [markdown]
# **Most cars in the dataset have a price between 0 and 100,000 and an odometer between 0 and 2000,000.**

# %% [markdown]
# ### Visualize Drive

# %% [markdown]
# #### 1. Number of cars vs drive

# %%
cars_per_drive = df_temp['drive'].value_counts()
cars_per_drive
# Out:
# drive
# 4wd    131904
# fwd    105517
# rwd     58892
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 6));
bar = ax.bar(cars_per_drive.index.tolist(), cars_per_drive);

# Customize the bar
ax.set(title="Used Cars per Drive", xlabel="Drive Type", ylabel='Number of Cars');

# %% [markdown]
# **The dataset comprises more than 120,000 cars with four-wheel drive, over 100,000 with front-wheel drive, and approximately 60,000 with rear-wheel drive.**

# %% [markdown]
# #### 2. Car price vs drive

# %%
# Box plot
plt.figure(figsize=(10, 6))
ax = sns.boxplot(x='drive', y='price', data=df_temp)
plt.title('Price Distribution per Drive Type')
plt.xlabel('Drive Type')
plt.ylabel('Price')

ax.set_yscale('log')
plt.show()

# %%
calculate_price_quartiles_by_column("drive", df_temp)
# Out:
# Below are the Q1, Q2 (median), & Q3 values:
# Q1 (First Quartile): represents the lower quartile, 25% of the data points are less than or equal to Q1
# Q2 (Median): represents the middle quartile, dividing the dataset into two equal parts
# Q3 (Third Quartile): represents the upper quartile, 75% of the data points are less than or equal to Q3
#
# Price distribution per drive:
# 4wd: Q1: 7500.0, Median: 17999.0, Q3: 32500.0
# Rwd: Q1: 7500.0, Median: 17500.0, Q3: 29500.0
# Fwd: Q1: 4950.0, Median: 9495.0, Q3: 16950.0

# %% [markdown]
# **The majority of cars with rear-wheel drive and four-wheel drive are priced between `$8,000` and `$32,000`, whereas front-wheel drive cars are priced in the range of `$5,000` to `$17,000`.
#  There are outliers present in the `price` column.**

# %% [markdown]
# #### 3. Average price per drive type

# %%
# Bar plot
plot_price_average_per_column("drive", df_temp)

# %%
# Calculate average prices for each drive type
calculate_average_price_by_column("drive", df_temp)
# Out:
# Below are the average prices per drive values:
# 4wd: $112029.80
# Rwd: $40795.62
# Fwd: $15300.88

# %% [markdown]
# **The average of the price of cars per drive type are:**
# * **Four-wheel drive** (4wd) is over 112,000.
# * **Rear-wheel drive** (rwd) is over 40,000.
# * **Front-wheel drive** (fwd) is over 15,000.

# %% [markdown]
# ### Visualize Transmission

# %% [markdown]
# #### 1. Car price vs transmission type

# %%
cars_per_transmission = df_temp['transmission'].value_counts()
cars_per_transmission
# Out:
# transmission
# automatic    336524
# other         62682
# manual        25118
# Name: count, dtype: int64

# %%
# Box plot
plot_price_distribution_per_column("transmission", df_temp)

# %%
## Calculate Q1 and Q2 (median) and Q3 for each group
calculate_price_quartiles_by_column("transmission", df_temp)
# Out:
# Below are the Q1, Q2 (median), & Q3 values:
# Q1 (First Quartile): represents the lower quartile, 25% of the data points are less than or equal to Q1
# Q2 (Median): represents the middle quartile, dividing the dataset into two equal parts
# Q3 (Third Quartile): represents the upper quartile, 75% of the data points are less than or equal to Q3
#
# Price distribution per transmission:
# Other: Q1: 20590.0, Median: 27990.0, Q3: 34990.0
# Automatic: Q1: 4999.0, Median: 11450.0, Q3: 22775.0
# Manual: Q1: 4500.0, Median: 9000.0, Q3: 18995.0

# %% [markdown]
# **The prices of the majority of cars with automatic and manual transmission range approximately from `$4,000` & `$22.000`, while the prices of cars with transmission catagory other ranges from about `$20,000` to approximately `$34,000`**

# %% [markdown]
# #### 2. Average price per transmission type

# %%
plot_price_average_per_column("transmission", df_temp)

# %%
# Average price per transmission
calculate_average_price_by_column("transmission", df_temp)
# Out:
# Below are the average prices per transmission values:
# Manual: $198416.34
# Automatic: $74881.00
# Other: $30003.79

# %% [markdown]
# **The average of the price of cars per transmission:**
# * **Automatic** is 75,000.
# * **Manual** is 198,000.
# * **Other** is 30,000.

# %% [markdown]
# ### Visualize Fuel

# %% [markdown]
# #### 1. Car price vs fuel type

# %%
# Box plot
plot_price_distribution_per_column("fuel", df_temp)

# %%
calculate_price_quartiles_by_column("fuel", df_temp)
# Out:
# Below are the Q1, Q2 (median), & Q3 values:
# Q1 (First Quartile): represents the lower quartile, 25% of the data points are less than or equal to Q1
# Q2 (Median): represents the middle quartile, dividing the dataset into two equal parts
# Q3 (Third Quartile): represents the upper quartile, 75% of the data points are less than or equal to Q3
#
# Price distribution per fuel:
# Diesel: Q1: 11000.0, Median: 27990.0, Q3: 44900.0
# Other: Q1: 16495.0, Median: 25990.0, Q3: 33990.0
# Electric: Q1: 11590.0, Median: 22544.5, Q3: 36590.0
# Gas: Q1: 5495.0, Median: 11998.0, Q3: 23876.0
# Hybrid: Q1: 6512.5, Median: 11995.0, Q3: 19990.0

# %% [markdown]
# #### 2. Average price per fuel type

# %%
plot_price_average_per_column("fuel", df_temp)

# %%
calculate_average_price_by_column("fuel", df_temp)
# Out:
# Below are the average prices per fuel values:
# Diesel: $118177.69
# Gas: $73902.26
# Other: $66811.40
# Electric: $24648.36
# Hybrid: $14582.43

# %% [markdown]
# #### 3. Min, Max, Median, Mean price per fuel

# %%
# Get min, max, mean, median,  price per fuel type
m4_price_per_fuel = df_temp.groupby(["fuel"])["price"].agg(["min", "max", "mean", "median"]).reset_index()
m4_price_per_fuel.head()
# Out:
#        fuel  min         max      mean   median
# 0    diesel    0  1410065407 118177.69 27990.00
# 1  electric    0      130000  24648.36 22544.50
# 2       gas    0  3736928711  73902.26 11998.00
# 3    hybrid    0      109999  14582.43 11995.00
# 4     other    0  1234567890  66811.40 25990.00

# %%
fig, ax = plt.subplots(figsize=(15, 10))
x = np.arange(len(m4_price_per_fuel["fuel"]))  # the label locations
width = 0.2

r1 = ax.bar(x - width*1.5, round(m4_price_per_fuel["max"]), width)
r2 = ax.bar(x - width/2, round(m4_price_per_fuel["mean"]), width)
r3 = ax.bar(x+ width/2, round(m4_price_per_fuel["median"]), width)
r4 = ax.bar(x + width*1.5, round(m4_price_per_fuel["min"]), width)

ax.set_xticks(x, m4_price_per_fuel["fuel"])

ax.bar_label(r1, padding=4, fontsize=10)
ax.bar_label(r2, padding=4, fontsize=10)
ax.bar_label(r3, padding=4, fontsize=10)
ax.bar_label(r4, padding=4, fontsize=10)

ax.set_xlabel("Fuel Type")
ax.set_ylabel("Price")
ax.set_yscale('log')
ax.set_title("(Min, Max, Mean, Median) Price per Fuel Type", fontsize=20)

fig.tight_layout()

plt.legend(['Max', 'Mean', 'Median', 'Min']);

# %% [markdown]
# ### Visualize Condition

# %% [markdown]
# #### 1. Price distribution per condition

# %%
# Box plot
plot_price_distribution_per_column("condition", df_temp)

# %%
calculate_price_quartiles_by_column("condition", df_temp)
# Out:
# Below are the Q1, Q2 (median), & Q3 values:
# Q1 (First Quartile): represents the lower quartile, 25% of the data points are less than or equal to Q1
# Q2 (Median): represents the middle quartile, dividing the dataset into two equal parts
# Q3 (Third Quartile): represents the upper quartile, 75% of the data points are less than or equal to Q3
#
# Price distribution per condition:
# Good: Q1: 7900.0, Median: 19995.0, Q3: 30990.0
# New: Q1: 1000.0, Median: 15900.0, Q3: 35114.0
# Like new: Q1: 6800.0, Median: 13950.0, Q3: 25000.0
# Excellent: Q1: 5999.5, Median: 10995.0, Q3: 18990.0
# Fair: Q1: 1500.0, Median: 2800.0, Q3: 4900.0
# Salvage: Q1: 950.0, Median: 1800.0, Q3: 4500.0

# %% [markdown]
# #### 2. Average price per condition

# %%
# Bar plot
plot_price_average_per_column("condition", df_temp)

# %%
calculate_average_price_by_column("condition", df_temp)
# Out:
# Below are the average prices per condition values:
# Fair: $761090.01
# Excellent: $51346.83
# Like new: $36402.04
# Good: $32545.20
# New: $23657.27
# Salvage: $3605.53

# %% [markdown]
# ### Visualize Cylinders

# %% [markdown]
# #### 1. User cars per cylinders

# %%
plot_column_frequancy("cylinders", df_temp)

# %% [markdown]
# #### 2. Price distribution per cylinders

# %%
# Box plot
plot_price_distribution_per_column("cylinders", df_temp)

# %%
calculate_price_quartiles_by_column("cylinders", df_temp)
# Out:
# Below are the Q1, Q2 (median), & Q3 values:
# Q1 (First Quartile): represents the lower quartile, 25% of the data points are less than or equal to Q1
# Q2 (Median): represents the middle quartile, dividing the dataset into two equal parts
# Q3 (Third Quartile): represents the upper quartile, 75% of the data points are less than or equal to Q3
#
# Price distribution per cylinders:
# 12 cylinders: Q1: 10000.0, Median: 28990.0, Q3: 65995.0
# 8 cylinders: Q1: 7900.0, Median: 18900.0, Q3: 33895.0
# 10 cylinders: Q1: 4995.0, Median: 14995.0, Q3: 28944.0
# 6 cylinders: Q1: 5500.0, Median: 13995.0, Q3: 27655.0
# Other: Q1: 2650.0, Median: 9991.5, Q3: 24999.0
# 3 cylinders: Q1: 5000.0, Median: 9990.0, Q3: 17989.5
# 4 cylinders: Q1: 4750.0, Median: 8500.0, Q3: 14577.5
# 5 cylinders: Q1: 3995.0, Median: 6200.0, Q3: 8999.0

# %% [markdown]
# #### 3. Average price per cylinders

# %%
# Bar plot
plot_price_average_per_column("cylinders", df_temp)

# %%
calculate_average_price_by_column("cylinders", df_temp)
# Out:
# Below are the average prices per cylinders values:
# 8 cylinders: $139595.72
# 6 cylinders: $58696.32
# 12 cylinders: $54299.38
# 10 cylinders: $21507.80
# Other: $17110.08
# 3 cylinders: $12297.00
# 4 cylinders: $10545.30
# 5 cylinders: $7842.78

# %% [markdown]
# ### Visualize Size

# %% [markdown]
# #### 1. Average price per size

# %%
# Bar plot
plot_price_average_per_column("size", df_temp)

# %%
calculate_average_price_by_column("size", df_temp)
# Out:
# Below are the average prices per size values:
# Mid-size: $120018.14
# Full-size: $99169.48
# Compact: $17510.31
# Sub-compact: $12266.98

# %% [markdown]
# #### 2. Price distribution per size

# %%
# Box plot
plot_price_distribution_per_column("size", df_temp)

# %%
calculate_price_quartiles_by_column("size", df_temp)
# Out:
# Below are the Q1, Q2 (median), & Q3 values:
# Q1 (First Quartile): represents the lower quartile, 25% of the data points are less than or equal to Q1
# Q2 (Median): represents the middle quartile, dividing the dataset into two equal parts
# Q3 (Third Quartile): represents the upper quartile, 75% of the data points are less than or equal to Q3
#
# Price distribution per size:
# Full-size: Q1: 4995.0, Median: 10995.0, Q3: 22000.0
# Mid-size: Q1: 4300.0, Median: 8495.0, Q3: 15995.0
# Sub-compact: Q1: 4500.0, Median: 7995.0, Q3: 14995.0
# Compact: Q1: 3988.0, Median: 7897.0, Q3: 14000.0

# %% [markdown]
# ### Visualize Vehicle Type

# %% [markdown]
# #### 1. Average price per vehicle type

# %%
# Bar plot
plot_price_average_per_column("type", df_temp)

# %%
calculate_average_price_by_column("type", df_temp)
# Out:
# Below are the average prices per type values:
# Pickup: $144751.64
# Suv: $34434.05
# Truck: $29383.58
# Other: $24743.59
# Coupe: $21937.56
# Convertible: $19999.77
# Van: $17487.60
# Sedan: $15950.19
# Offroad: $15813.09
# Hatchback: $14384.51
# Bus: $14105.62
# Wagon: $13273.91
# Mini-van: $9234.09

# %% [markdown]
# #### 2. Average price per vehicle type

# %%
# Box plot
plot_price_distribution_per_column("type", df_temp)

# %%
calculate_price_quartiles_by_column("type", df_temp)
# Out:
# Below are the Q1, Q2 (median), & Q3 values:
# Q1 (First Quartile): represents the lower quartile, 25% of the data points are less than or equal to Q1
# Q2 (Median): represents the middle quartile, dividing the dataset into two equal parts
# Q3 (Third Quartile): represents the upper quartile, 75% of the data points are less than or equal to Q3
#
# Price distribution per type:
# Pickup: Q1: 16500.0, Median: 27990.0, Q3: 35950.0
# Other: Q1: 12500.0, Median: 25590.0, Q3: 34990.0
# Truck: Q1: 7000.0, Median: 20999.0, Q3: 35998.0
# Coupe: Q1: 7500.0, Median: 18516.5, Q3: 32590.0
# Convertible: Q1: 7800.0, Median: 15000.0, Q3: 26344.0
# Van: Q1: 6995.0, Median: 14995.0, Q3: 25000.0
# Hatchback: Q1: 6500.0, Median: 13950.0, Q3: 19990.0
# Suv: Q1: 5999.0, Median: 13295.0, Q3: 23458.75
# Offroad: Q1: 6500.0, Median: 12500.0, Q3: 23000.0
# Wagon: Q1: 6000.0, Median: 11995.0, Q3: 18500.0
# Bus: Q1: 5500.0, Median: 10900.0, Q3: 21900.0
# Sedan: Q1: 4995.0, Median: 9995.0, Q3: 18990.0
# Mini-van: Q1: 3800.0, Median: 6988.0, Q3: 12500.0

# %% [markdown]
# ## Check cars with price of 0

# %%
df_free_cars = df_temp[df_temp["price"] == 0]
df_free_cars
# Out:
#                 id   region  price       year manufacturer          model  \
# 10      7218893038  el paso      0        NaT          NaN            NaN
# 11      7218325704  el paso      0        NaT          NaN            NaN
# 12      7217788283  el paso      0        NaT          NaN            NaN
# 13      7217147606  el paso      0        NaT          NaN            NaN
# 14      7209027818  el paso      0        NaT          NaN            NaN
# ...            ...      ...    ...        ...          ...            ...
# 426764  7303347225  wyoming      0 2018-01-01          NaN  peterbilt 579
# 426812  7302877815  wyoming      0 2006-01-01       toyota       scion tc
# 426832  7302353283  wyoming      0 2004-01-01       toyota          prius
# 426836  7302301268  wyoming      0 2018-01-01          ram           2500
# 426868  7301843288  wyoming      0 2010-01-01       toyota          venza
#
#         condition    cylinders    fuel  odometer title_status transmission  \
# 10            NaN          NaN     NaN       NaN          NaN          NaN
# 11            NaN          NaN     NaN       NaN          NaN          NaN
# 12            NaN          NaN     NaN       NaN          NaN          NaN
# 13            NaN          NaN     NaN       NaN          NaN          NaN
# 14            NaN          NaN     NaN       NaN          NaN          NaN
# ...           ...          ...     ...       ...          ...          ...
# 426764        NaN          NaN  diesel      1.00        clean    automatic
# 426812  excellent  4 cylinders     gas 195000.00        clean    automatic
# 426832  excellent  4 cylinders  hybrid 239000.00        clean    automatic
# 426836  excellent  6 cylinders  diesel  20492.00        clean    automatic
# 426868  excellent  6 cylinders     gas 155000.00        clean    automatic
#
#        drive       size   type paint_color  \
# 10       NaN        NaN    NaN         NaN
# 11       NaN        NaN    NaN         NaN
# 12       NaN        NaN    NaN         NaN
# 13       NaN        NaN    NaN         NaN
# 14       NaN        NaN    NaN         NaN
# ...      ...        ...    ...         ...
# 426764   NaN        NaN    NaN         NaN
# 426812   fwd        NaN    NaN      silver
# 426832   fwd        NaN    NaN        blue
# 426836   4wd  full-size  truck       white
# 426868   4wd        NaN    NaN        blue
#
#                                               description state  \
# 10                                                    NaN    tx
# 11                                                    NaN    tx
# 12                                                    NaN    tx
# 13                                                    NaN    tx
# 14                                                    NaN    tx
# ...                                                   ...   ...
# 426764  ◄ PRICES STARTING AT $57,500 ($57,500 and up, ...    wy
# 426812  2006 *** TOYOTA SCION TC  ***    Call or Text ...    wy
# 426832  2004 *** TOYOTA PRIUS  ***    Call or Text "To...    wy
# 426836  Phone: 320-275-2150   2018 RAM 2500 Tradesman ...    wy
# 426868  2010 *** TOYOTA VENZA AWD V6  ***    Call or T...    wy
#
#               posting_date  posting_year
# 10                     NaT           NaN
# 11                     NaT           NaN
# 12                     NaT           NaN
# 13                     NaT           NaN
# 14                     NaT           NaN
# ...                    ...           ...
# 426764 2021-04-07 15:15:00       2021.00
# 426812 2021-04-06 17:00:01       2021.00
# 426832 2021-04-05 17:00:05       2021.00
# 426836 2021-04-05 15:18:04       2021.00
# 426868 2021-04-04 17:00:04       2021.00
#
# [32895 rows x 20 columns]

# %%
df_free_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32895 entries, 10 to 426868
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            32895 non-null  int64
#  1   region        32895 non-null  object
#  2   price         32895 non-null  int64
#  3   year          32863 non-null  datetime64[ns]
#  4   manufacturer  31434 non-null  object
#  5   model         32319 non-null  object
#  6   condition     10180 non-null  object
#  7   cylinders     15627 non-null  object
#  8   fuel          32476 non-null  object
#  9   odometer      30785 non-null  float64
#  10  title_status  32387 non-null  object
#  11  transmission  32162 non-null  object
#  12  drive         22582 non-null  object
#  13  size          9467 non-null   object
#  14  type          25969 non-null  object
#  15  paint_color   19841 non-null  object
#  16  description   32889 non-null  object
#  17  state         32895 non-null  object
#  18  posting_date  32889 non-null  datetime64[ns]
#  19  posting_year  32889 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(2), object(14)
# memory usage: 5.3+ MB

# %% [markdown]
# Over 32000 cars have 0 as a value for the price.
# The condition column is null 22000 of those cars.
# The description column in some cases contains a range price.
# The description column contains personal information in a lot of the cases, such as moblie numbers.

# %% [markdown]
# ### Visulize cars with price 0 per condition

# %%
plot_column_frequancy("condition", df_free_cars);

# %%
df_free_cars.isna().sum()
# Out:
# id                  0
# region              0
# price               0
# year               32
# manufacturer     1461
# model             576
# condition       22715
# cylinders       17268
# fuel              419
# odometer         2110
# title_status      508
# transmission      733
# drive           10313
# size            23428
# type             6926
# paint_color     13054
# description         6
# state               0
# posting_date        6
# posting_year        6
# dtype: int64

# %%
# Check missing data percentage
np.round(df_free_cars.isnull().sum()/len(df_free_cars)*100)
# Out:
# id              0.00
# region          0.00
# price           0.00
# year            0.00
# manufacturer    4.00
# model           2.00
# condition      69.00
# cylinders      52.00
# fuel            1.00
# odometer        6.00
# title_status    2.00
# transmission    2.00
# drive          31.00
# size           71.00
# type           21.00
# paint_color    40.00
# description     0.00
# state           0.00
# posting_date    0.00
# posting_year    0.00
# dtype: float64

# %%
# Convert non-numeric values to NaNs
# df_temp_numeric = df_temp.apply(pd.to_numeric, errors='coerce')
# df_temp_numeric = df_temp.dropna(axis=1, subset=["region", "year", "manufacturer", "model", "condition", "cylinders", "fuel", "title_status", "transmission", "drive", "size", "type", "paint_color", "image_url", "description", "state", "posting_date"])

# Drop columns where any of the specified rows contain NaN values
df_temp_numeric = df_temp.drop(["id", "region", "year", "manufacturer", "model", "condition", "cylinders", "fuel", "title_status", "transmission", "drive", "size", "type", "paint_color", "description", "state", "posting_date", "posting_year"], axis=1)

# Convert the remaining DataFrame to numeric values where possible
# df_temp_numeric = df_temp_cleaned.apply(pd.to_numeric, errors='coerce')
# Compute the correlation matrix
corr_matrix = df_temp_numeric.corr()

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, 
            linewidths=0.5, 
            fmt=".2f", 
            cmap="YlGnBu",
            annot=True)
plt.title('Correlation Matrix')
plt.show()

# %%
# Export cleaned data
df_temp_cleaned = df_temp.copy()
df_temp_cleaned.to_csv('df_cleaned.csv', index=False)

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# Link to  [data preparation notebook](2.data_prep.ipynb)

# %% [markdown]
# ## Modelling

# %% [markdown]
# Link to [regression modelling notebook](3.reg_modelling.ipynb)
#
# Link to [deep learning modelling notebook](4.tensorFlow_modelling.ipynb)
